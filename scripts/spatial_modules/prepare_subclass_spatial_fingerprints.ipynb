# %%
import os

import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
from sklearn.neighbors import NearestNeighbors

import scanpy as sc
sc.settings.n_jobs = 56
sc.settings.set_figure_params(dpi=180, dpi_save=300, frameon=False, figsize=(4, 4), fontsize=8, facecolor='white')

import sys
sys.path.append('/home/xingjiepan/Softwares/ZhuangLab/MERFISH_analysis/basic/util')
from plot import get_color_mapping_df

# %%
def calc_spatial_fingerprint_df_2d(adata_query, adata_ref, cell_type_col, 
                              slice_col='slice_id', xy_cols=['global_x', 'global_y'],
                              K = 50):
    
    # Convert the cell types to indices in the neighborhood vector
    ct_to_neighbor_id_dict = {}

    unique_cts = np.unique(adata_ref.obs[cell_type_col])
    
    for i in range(len(unique_cts)):
        ct_to_neighbor_id_dict[unique_cts[i]] = i

    L_neighbor_vec = len(unique_cts)
    
    # Generate a matrix of neighborhood cell types
    all_knn_neighor_vecs = np.zeros((adata_query.shape[0], L_neighbor_vec), dtype=np.float32)


    # Iterate through the slices
    slice_ids = np.unique(adata_query.obs[slice_col])
    for slice_id in slice_ids:
        print(f'Generate neighbor vectors for slice {slice_id}')
    
        slice_mask_q = adata_query.obs[slice_col] == slice_id
        df_slice_q = adata_query.obs[slice_mask_q]
        slice_mask_r = adata_ref.obs[slice_col] == slice_id
        df_slice_r = adata_ref.obs[slice_mask_r]
    
        # Calculate spatial K nearest neighbors
        X_spatial_query = np.array(df_slice_q[xy_cols])
        X_spatial_ref = np.array(df_slice_r[xy_cols])

        nbrs = NearestNeighbors(n_neighbors=K, algorithm='ball_tree').fit(X_spatial_ref)
        distances, indices = nbrs.kneighbors(X_spatial_query)
        print('Mean KNN distance =', np.mean(distances))
    
        # Get the cell types of each cell's KNN
        knn_cts = np.array(df_slice_r[cell_type_col])[indices]
    
        # Generate the matrix of neighbor cell types
        knn_neighbor_vecs = np.zeros((df_slice_q.shape[0], L_neighbor_vec))
        for i in range(df_slice_q.shape[0]):
            
            # Estimate the charasteristic neighbor distance
            neighbor_R0 = 2 * np.quantile(distances[i], max(0.1, 5 / K))
            for j in range(K):
                ct_neighbor_id = ct_to_neighbor_id_dict[knn_cts[i, j]]
            
                knn_neighbor_vecs[i, ct_neighbor_id] += np.exp(- (distances[i, j] / neighbor_R0) ** 2)
            
        all_knn_neighor_vecs[slice_mask_q] = knn_neighbor_vecs
        
    return pd.DataFrame(all_knn_neighor_vecs, adata_query.obs.index, list(unique_cts))

# %%
# Load the data
adata = sc.read_h5ad('/home/xingjiepan/data/whole_brain/analysis/20230723_final_integration/integration_workspace/adata_merfish_label_transfer.h5ad')
adata
# Out:
# AnnData object with n_obs × n_vars = 9343481 × 1122
#     obs: 'integration_partition_transfer', 'integration_partition_confidence', 'subclass_label_transfer', 'subclass_label_confidence', 'cl_transfer', 'cl_confidence', 'cluster_cosine_similarity', 'adjusted_subclass_label_confidence', 'adjusted_cl_confidence'

# %%
# Filter out low quality and poorly mapped cells
adata = adata[adata.obs['adjusted_subclass_label_confidence'] > 0.8]
adata = adata[adata.obs['adjusted_cl_confidence'] > 0.5]
adata = adata[adata.obs['subclass_label_transfer'] != 'LQ']
adata
# Out:
# View of AnnData object with n_obs × n_vars = 6461549 × 1122
#     obs: 'integration_partition_transfer', 'integration_partition_confidence', 'subclass_label_transfer', 'subclass_label_confidence', 'cl_transfer', 'cl_confidence', 'cluster_cosine_similarity', 'adjusted_subclass_label_confidence', 'adjusted_cl_confidence'

# %%
# Get the spatial coordinates from the metadata file
cell_metadata_df = pd.read_csv('/home/xingjiepan/data/whole_brain/MERFISH/20230602_cellpose2/cell_metadata_cp2.csv', 
                               index_col=0)
adata.obs['slice_id'] = cell_metadata_df['slice_id']
adata.obs['center_x'] = cell_metadata_df['center_x']
adata.obs['center_y'] = cell_metadata_df['center_y']

adata = adata[~adata.obs['slice_id'].isna()]
adata
# Out:
# /tmp/ipykernel_614767/2650207157.py:4: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   adata.obs['slice_id'] = cell_metadata_df['slice_id']
# View of AnnData object with n_obs × n_vars = 6461532 × 1122
#     obs: 'integration_partition_transfer', 'integration_partition_confidence', 'subclass_label_transfer', 'subclass_label_confidence', 'cl_transfer', 'cl_confidence', 'cluster_cosine_similarity', 'adjusted_subclass_label_confidence', 'adjusted_cl_confidence', 'slice_id', 'center_x', 'center_y'

# %%
# Remove cell types that are not informative for defining spatial modules in the reference cell types
subclasses_to_remove = ['LQ', 'Endo NN', 'SMC NN', 'Peri NN', 'VLMC NN', 'BAM NN', 'DC NN', 'Lymphoid NN',
                       'Microglia NN', 'Monocytes NN',]
adata_ref = adata[~adata.obs['subclass_label_transfer'].isin(subclasses_to_remove)]
adata_ref
# Out:
# View of AnnData object with n_obs × n_vars = 5198857 × 1122
#     obs: 'integration_partition_transfer', 'integration_partition_confidence', 'subclass_label_transfer', 'subclass_label_confidence', 'cl_transfer', 'cl_confidence', 'cluster_cosine_similarity', 'adjusted_subclass_label_confidence', 'adjusted_cl_confidence', 'slice_id', 'center_x', 'center_y'

# %%
# %%time
# Generate data frames of spatial fingerprint vectors
spatial_fingerprint_df_subclass = calc_spatial_fingerprint_df_2d(adata, adata_ref, 'subclass_label_transfer',
                                                                xy_cols=['center_x', 'center_y'])
# Out:
# Generate neighbor vectors for slice co1_slice1
# Mean KNN distance = 54.77528023572422
# Generate neighbor vectors for slice co1_slice10
# Mean KNN distance = 61.3117372504746
# Generate neighbor vectors for slice co1_slice11
# Mean KNN distance = 60.17967477710854
# Generate neighbor vectors for slice co1_slice12
# Mean KNN distance = 70.86916604299168
# Generate neighbor vectors for slice co1_slice13
# Mean KNN distance = 90.81309210578625
# Generate neighbor vectors for slice co1_slice14
# Mean KNN distance = 86.35911360053306
# Generate neighbor vectors for slice co1_slice15
# Mean KNN distance = 89.51864100330845
# Generate neighbor vectors for slice co1_slice16
# Mean KNN distance = 87.09553513523981
# Generate neighbor vectors for slice co1_slice17
# Mean KNN distance = 101.34208421093629
# Generate neighbor vectors for slice co1_slice18
# Mean KNN distance = 116.656991857002
# Generate neighbor vectors for slice co1_slice19
# Mean KNN distance = 94.51453399616733
# Generate neighbor vectors for slice co1_slice2
# Mean KNN distance = 61.86729312651176
# Generate neighbor vectors for slice co1_slice20
# Mean KNN distance = 94.4371702983125
# Generate neighbor vectors for slice co1_slice21
# Mean KNN distance = 99.08722475131884
# Generate neighbor vectors for slice co1_slice22
# Mean KNN distance = 96.33683007227663
# Generate neighbor vectors for slice co1_slice23
# Mean KNN distance = 80.46094301353115
# Generate neighbor vectors for slice co1_slice25
# Mean KNN distance = 75.4215668360056
# Generate neighbor vectors for slice co1_slice26
# Mean KNN distance = 86.75340049714033
# Generate neighbor vectors for slice co1_slice27
# Mean KNN distance = 98.24959947062831
# Generate neighbor vectors for slice co1_slice28
# Mean KNN distance = 81.59397548529161
# Generate neighbor vectors for slice co1_slice3
# Mean KNN distance = 76.48662636645291
# Generate neighbor vectors for slice co1_slice30
# Mean KNN distance = 75.6722111360478
# Generate neighbor vectors for slice co1_slice31
# Mean KNN distance = 82.56498699030422
# Generate neighbor vectors for slice co1_slice32
# Mean KNN distance = 95.45431666863479
# Generate neighbor vectors for slice co1_slice33
# Mean KNN distance = 81.41632311411097
# Generate neighbor vectors for slice co1_slice34
# Mean KNN distance = 74.70530561132414
# Generate neighbor vectors for slice co1_slice35
# Mean KNN distance = 104.78844439616138
# Generate neighbor vectors for slice co1_slice36
# Mean KNN distance = 78.20980674726084
# Generate neighbor vectors for slice co1_slice37
# Mean KNN distance = 93.14215051543107
# Generate neighbor vectors for slice co1_slice39
# Mean KNN distance = 76.44372380017992
# Generate neighbor vectors for slice co1_slice4
# Mean KNN distance = 54.65500557315322
# Generate neighbor vectors for slice co1_slice40
# Mean KNN distance = 105.03996295376182
# Generate neighbor vectors for slice co1_slice41
# Mean KNN distance = 79.97996530400114
# Generate neighbor vectors for slice co1_slice41_p2
# Mean KNN distance = 82.74714988140212
# Generate neighbor vectors for slice co1_slice42
# Mean KNN distance = 99.05577960440428
# Generate neighbor vectors for slice co1_slice44
# Mean KNN distance = 78.77870847668353
# Generate neighbor vectors for slice co1_slice45
# Mean KNN distance = 76.80241867887011
# Generate neighbor vectors for slice co1_slice46
# Mean KNN distance = 97.145672012296
# Generate neighbor vectors for slice co1_slice47
# Mean KNN distance = 79.47111039695606
# Generate neighbor vectors for slice co1_slice48
# Mean KNN distance = 107.6564624500272
# Generate neighbor vectors for slice co1_slice49
# Mean KNN distance = 79.04389784172474
# Generate neighbor vectors for slice co1_slice5
# Mean KNN distance = 57.438282372753804
# Generate neighbor vectors for slice co1_slice50
# Mean KNN distance = 73.00045396565507
# Generate neighbor vectors for slice co1_slice51
# Mean KNN distance = 94.43721861426474
# Generate neighbor vectors for slice co1_slice52
# Mean KNN distance = 77.4334268277474
# Generate neighbor vectors for slice co1_slice53
# Mean KNN distance = 101.7184323089361
# Generate neighbor vectors for slice co1_slice54
# Mean KNN distance = 75.17565359813769
# Generate neighbor vectors for slice co1_slice55
# Mean KNN distance = 74.42557920420455
# Generate neighbor vectors for slice co1_slice56
# Mean KNN distance = 99.97821574957347
# Generate neighbor vectors for slice co1_slice57
# Mean KNN distance = 72.09484156572185
# Generate neighbor vectors for slice co1_slice58
# Mean KNN distance = 93.55392339225604
# Generate neighbor vectors for slice co1_slice59
# Mean KNN distance = 69.55598181376203
# Generate neighbor vectors for slice co1_slice6
# Mean KNN distance = 55.05975869358457
# Generate neighbor vectors for slice co1_slice60
# Mean KNN distance = 84.41516397788082
# Generate neighbor vectors for slice co1_slice61
# Mean KNN distance = 71.01188695929594
# Generate neighbor vectors for slice co1_slice62
# Mean KNN distance = 82.5171743088644
# Generate neighbor vectors for slice co1_slice63
# Mean KNN distance = 77.32484343607277
# Generate neighbor vectors for slice co1_slice65
# Mean KNN distance = 83.61258146994518
# Generate neighbor vectors for slice co1_slice66
# Mean KNN distance = 80.1001665461122
# Generate neighbor vectors for slice co1_slice67
# Mean KNN distance = 80.0934154398478
# Generate neighbor vectors for slice co1_slice68
# Mean KNN distance = 76.26325577521405
# Generate neighbor vectors for slice co1_slice7
# Mean KNN distance = 59.29528648073924
# Generate neighbor vectors for slice co1_slice70
# Mean KNN distance = 97.6910825553001
# Generate neighbor vectors for slice co1_slice71
# Mean KNN distance = 85.6503400074947
# Generate neighbor vectors for slice co1_slice72
# Mean KNN distance = 89.06341266441034
# Generate neighbor vectors for slice co1_slice73
# Mean KNN distance = 80.13117488105819
# Generate neighbor vectors for slice co1_slice8
# Mean KNN distance = 67.32521506648145
# Generate neighbor vectors for slice co1_slice9
# Mean KNN distance = 52.07629509586593
# Generate neighbor vectors for slice co2_slice1
# Mean KNN distance = 59.43498186077787
# Generate neighbor vectors for slice co2_slice10
# Mean KNN distance = 55.485799490941716
# Generate neighbor vectors for slice co2_slice100
# Mean KNN distance = 76.15947246999656
# Generate neighbor vectors for slice co2_slice101
# Mean KNN distance = 85.25595786104593
# Generate neighbor vectors for slice co2_slice102
# Mean KNN distance = 78.81166700008379
# Generate neighbor vectors for slice co2_slice103
# Mean KNN distance = 78.8757268797544
# Generate neighbor vectors for slice co2_slice104
# Mean KNN distance = 79.90942495780999
# Generate neighbor vectors for slice co2_slice105
# Mean KNN distance = 83.8058209518304
# Generate neighbor vectors for slice co2_slice106
# Mean KNN distance = 75.80931262722682
# Generate neighbor vectors for slice co2_slice107
# Mean KNN distance = 80.3343343526717
# Generate neighbor vectors for slice co2_slice108
# Mean KNN distance = 80.84418539403434
# Generate neighbor vectors for slice co2_slice109
# Mean KNN distance = 82.05865460866801
# Generate neighbor vectors for slice co2_slice11
# Mean KNN distance = 61.329081013641996
# Generate neighbor vectors for slice co2_slice110
# Mean KNN distance = 79.71627984312431
# Generate neighbor vectors for slice co2_slice111
# Mean KNN distance = 87.84749699799502
# Generate neighbor vectors for slice co2_slice112
# Mean KNN distance = 84.27865662566505
# Generate neighbor vectors for slice co2_slice113
# Mean KNN distance = 81.95206341891105
# Generate neighbor vectors for slice co2_slice114
# Mean KNN distance = 79.65189390134421
# Generate neighbor vectors for slice co2_slice115
# Mean KNN distance = 88.15963307243356
# Generate neighbor vectors for slice co2_slice116
# Mean KNN distance = 82.66801026840953
# Generate neighbor vectors for slice co2_slice117
# Mean KNN distance = 83.1046247597227
# Generate neighbor vectors for slice co2_slice118
# Mean KNN distance = 77.36356609141548
# Generate neighbor vectors for slice co2_slice119
# Mean KNN distance = 73.54030423604266
# Generate neighbor vectors for slice co2_slice12
# Mean KNN distance = 58.43344088910817
# Generate neighbor vectors for slice co2_slice120
# Mean KNN distance = 75.5084374111449
# Generate neighbor vectors for slice co2_slice121
# Mean KNN distance = 77.96167910571391
# Generate neighbor vectors for slice co2_slice122
# Mean KNN distance = 71.17672856406388
# Generate neighbor vectors for slice co2_slice123
# Mean KNN distance = 82.21492717476796
# Generate neighbor vectors for slice co2_slice124
# Mean KNN distance = 84.46280557981443
# Generate neighbor vectors for slice co2_slice125
# Mean KNN distance = 81.4079114690481
# Generate neighbor vectors for slice co2_slice126
# Mean KNN distance = 81.13990467421196
# Generate neighbor vectors for slice co2_slice127
# Mean KNN distance = 84.93794821085501
# Generate neighbor vectors for slice co2_slice128
# Mean KNN distance = 85.5336165485221
# Generate neighbor vectors for slice co2_slice129
# Mean KNN distance = 79.31510204877885
# Generate neighbor vectors for slice co2_slice13
# Mean KNN distance = 57.67032914030486
# Generate neighbor vectors for slice co2_slice130
# Mean KNN distance = 78.06763939608865
# Generate neighbor vectors for slice co2_slice131
# Mean KNN distance = 84.12422469557396
# Generate neighbor vectors for slice co2_slice132
# Mean KNN distance = 82.93547460769177
# Generate neighbor vectors for slice co2_slice133
# Mean KNN distance = 78.40859188185601
# Generate neighbor vectors for slice co2_slice134
# Mean KNN distance = 77.39864075344178
# Generate neighbor vectors for slice co2_slice135
# Mean KNN distance = 83.8336785702018
# Generate neighbor vectors for slice co2_slice136
# Mean KNN distance = 89.52739881228771
# Generate neighbor vectors for slice co2_slice137
# Mean KNN distance = 88.58615672025248
# Generate neighbor vectors for slice co2_slice138
# Mean KNN distance = 79.65895009939291
# Generate neighbor vectors for slice co2_slice139
# Mean KNN distance = 85.37191074972645
# Generate neighbor vectors for slice co2_slice14
# Mean KNN distance = 56.16830035047146
# Generate neighbor vectors for slice co2_slice140
# Mean KNN distance = 90.0329489040574
# Generate neighbor vectors for slice co2_slice141
# Mean KNN distance = 86.91916750999356
# Generate neighbor vectors for slice co2_slice142
# Mean KNN distance = 85.35909217248589
# Generate neighbor vectors for slice co2_slice143
# Mean KNN distance = 95.72039457845614
# Generate neighbor vectors for slice co2_slice144
# Mean KNN distance = 90.15632646408486
# Generate neighbor vectors for slice co2_slice145
# Mean KNN distance = 91.03072009126751
# Generate neighbor vectors for slice co2_slice146
# Mean KNN distance = 87.63125114002403
# Generate neighbor vectors for slice co2_slice147
# Mean KNN distance = 87.0053536305707
# Generate neighbor vectors for slice co2_slice148
# Mean KNN distance = 81.66822536666915
# Generate neighbor vectors for slice co2_slice149
# Mean KNN distance = 92.78169414248116
# Generate neighbor vectors for slice co2_slice15
# Mean KNN distance = 56.03593602335759
# Generate neighbor vectors for slice co2_slice150
# Mean KNN distance = 79.93407909531649
# Generate neighbor vectors for slice co2_slice16
# Mean KNN distance = 63.92068359004418
# Generate neighbor vectors for slice co2_slice17
# Mean KNN distance = 69.35812707155581
# Generate neighbor vectors for slice co2_slice18
# Mean KNN distance = 55.522416196693506
# Generate neighbor vectors for slice co2_slice19
# Mean KNN distance = 70.58626026289002
# Generate neighbor vectors for slice co2_slice2
# Mean KNN distance = 54.26619305369948
# Generate neighbor vectors for slice co2_slice20
# Mean KNN distance = 53.264731212294116
# Generate neighbor vectors for slice co2_slice21
# Mean KNN distance = 54.64250259252238
# Generate neighbor vectors for slice co2_slice22
# Mean KNN distance = 54.15600740797248
# Generate neighbor vectors for slice co2_slice23
# Mean KNN distance = 60.89872682704178
# Generate neighbor vectors for slice co2_slice24
# Mean KNN distance = 56.48494875456837
# Generate neighbor vectors for slice co2_slice25
# Mean KNN distance = 61.76104377119673
# Generate neighbor vectors for slice co2_slice26
# Mean KNN distance = 69.07459309027412
# Generate neighbor vectors for slice co2_slice27
# Mean KNN distance = 85.18122631069735
# Generate neighbor vectors for slice co2_slice28
# Mean KNN distance = 73.11242886877504
# Generate neighbor vectors for slice co2_slice29
# Mean KNN distance = 87.78130450649682
# Generate neighbor vectors for slice co2_slice3
# Mean KNN distance = 57.50976437213535
# Generate neighbor vectors for slice co2_slice30
# Mean KNN distance = 76.01502366068823
# Generate neighbor vectors for slice co2_slice31
# Mean KNN distance = 81.2893528340399
# Generate neighbor vectors for slice co2_slice32
# Mean KNN distance = 87.28805873000722
# Generate neighbor vectors for slice co2_slice33
# Mean KNN distance = 87.14347711830852
# Generate neighbor vectors for slice co2_slice34
# Mean KNN distance = 90.75782167310628
# Generate neighbor vectors for slice co2_slice35
# Mean KNN distance = 95.96268476523181
# Generate neighbor vectors for slice co2_slice36
# Mean KNN distance = 102.31892766318298
# Generate neighbor vectors for slice co2_slice37
# Mean KNN distance = 109.80126330792817
# Generate neighbor vectors for slice co2_slice38
# Mean KNN distance = 98.09721351869021
# Generate neighbor vectors for slice co2_slice39
# Mean KNN distance = 105.52517318892967
# Generate neighbor vectors for slice co2_slice4
# Mean KNN distance = 56.94285016522393
# Generate neighbor vectors for slice co2_slice40
# Mean KNN distance = 92.26566731798619
# Generate neighbor vectors for slice co2_slice41
# Mean KNN distance = 102.54624459460226
# Generate neighbor vectors for slice co2_slice42
# Mean KNN distance = 95.72069343431825
# Generate neighbor vectors for slice co2_slice43
# Mean KNN distance = 95.79469674679005
# Generate neighbor vectors for slice co2_slice44
# Mean KNN distance = 89.85428846863023
# Generate neighbor vectors for slice co2_slice45
# Mean KNN distance = 100.51384629672894
# Generate neighbor vectors for slice co2_slice46
# Mean KNN distance = 78.63723690928386
# Generate neighbor vectors for slice co2_slice47
# Mean KNN distance = 81.78924239800341
# Generate neighbor vectors for slice co2_slice48
# Mean KNN distance = 82.49594207397892
# Generate neighbor vectors for slice co2_slice49
# Mean KNN distance = 85.05461297490561
# Generate neighbor vectors for slice co2_slice5
# Mean KNN distance = 53.911366146333236
# Generate neighbor vectors for slice co2_slice50
# Mean KNN distance = 78.31247695938167
# Generate neighbor vectors for slice co2_slice51
# Mean KNN distance = 84.84543601784128
# Generate neighbor vectors for slice co2_slice52
# Mean KNN distance = 79.38045744707865
# Generate neighbor vectors for slice co2_slice53
# Mean KNN distance = 81.72415894948108
# Generate neighbor vectors for slice co2_slice54
# Mean KNN distance = 73.69963652163067
# Generate neighbor vectors for slice co2_slice55
# Mean KNN distance = 97.09733783416961
# Generate neighbor vectors for slice co2_slice56
# Mean KNN distance = 77.41034116657217
# Generate neighbor vectors for slice co2_slice57
# Mean KNN distance = 81.80248924064804
# Generate neighbor vectors for slice co2_slice58
# Mean KNN distance = 83.51301002097931
# Generate neighbor vectors for slice co2_slice59
# Mean KNN distance = 88.2890723385451
# Generate neighbor vectors for slice co2_slice6
# Mean KNN distance = 57.53605257601682
# Generate neighbor vectors for slice co2_slice60
# Mean KNN distance = 78.17203578146001
# Generate neighbor vectors for slice co2_slice61
# Mean KNN distance = 84.01929175411304
# Generate neighbor vectors for slice co2_slice62
# Mean KNN distance = 81.65197717930545
# Generate neighbor vectors for slice co2_slice63
# Mean KNN distance = 83.42934998746969
# Generate neighbor vectors for slice co2_slice64
# Mean KNN distance = 79.53646118826971
# Generate neighbor vectors for slice co2_slice65
# Mean KNN distance = 103.55509704039794
# Generate neighbor vectors for slice co2_slice66
# Mean KNN distance = 73.55162760493766
# Generate neighbor vectors for slice co2_slice67
# Mean KNN distance = 81.41192223252853
# Generate neighbor vectors for slice co2_slice68
# Mean KNN distance = 82.99807600446776
# Generate neighbor vectors for slice co2_slice69
# Mean KNN distance = 89.14433877889047
# Generate neighbor vectors for slice co2_slice7
# Mean KNN distance = 63.13434740798608
# Generate neighbor vectors for slice co2_slice70
# Mean KNN distance = 79.99251055152219
# Generate neighbor vectors for slice co2_slice71
# Mean KNN distance = 84.69623331885647
# Generate neighbor vectors for slice co2_slice72
# Mean KNN distance = 85.82538753489476
# Generate neighbor vectors for slice co2_slice73
# Mean KNN distance = 83.64057239139157
# Generate neighbor vectors for slice co2_slice74
# Mean KNN distance = 85.22065173348885
# Generate neighbor vectors for slice co2_slice75
# Mean KNN distance = 78.83236218561412
# Generate neighbor vectors for slice co2_slice76
# Mean KNN distance = 81.65992971407955
# Generate neighbor vectors for slice co2_slice77
# Mean KNN distance = 83.1663811356352
# Generate neighbor vectors for slice co2_slice78
# Mean KNN distance = 77.02205797315139
# Generate neighbor vectors for slice co2_slice79
# Mean KNN distance = 80.83403925168932
# Generate neighbor vectors for slice co2_slice8
# Mean KNN distance = 52.98449967384243
# Generate neighbor vectors for slice co2_slice80
# Mean KNN distance = 74.98566468266492
# Generate neighbor vectors for slice co2_slice81
# Mean KNN distance = 81.54603431482138
# Generate neighbor vectors for slice co2_slice82
# Mean KNN distance = 85.84025046862631
# Generate neighbor vectors for slice co2_slice83
# Mean KNN distance = 82.7533078900878
# Generate neighbor vectors for slice co2_slice84
# Mean KNN distance = 86.48412726607539
# Generate neighbor vectors for slice co2_slice85
# Mean KNN distance = 78.98775453279299
# Generate neighbor vectors for slice co2_slice86
# Mean KNN distance = 78.44262227561372
# Generate neighbor vectors for slice co2_slice87
# Mean KNN distance = 82.25543261068124
# Generate neighbor vectors for slice co2_slice88
# Mean KNN distance = 76.89344926114445
# Generate neighbor vectors for slice co2_slice89
# Mean KNN distance = 82.20957300510977
# Generate neighbor vectors for slice co2_slice9
# Mean KNN distance = 71.2367106791417
# Generate neighbor vectors for slice co2_slice90
# Mean KNN distance = 76.22712570299043
# Generate neighbor vectors for slice co2_slice91
# Mean KNN distance = 83.95179438575786
# Generate neighbor vectors for slice co2_slice92
# Mean KNN distance = 78.93436379813983
# Generate neighbor vectors for slice co2_slice93
# Mean KNN distance = 81.55376533856733
# Generate neighbor vectors for slice co2_slice94
# Mean KNN distance = 84.9958529923671
# Generate neighbor vectors for slice co2_slice95
# Mean KNN distance = 90.1938241096899
# Generate neighbor vectors for slice co2_slice96
# Mean KNN distance = 81.78844881753571
# Generate neighbor vectors for slice co2_slice97
# Mean KNN distance = 83.81216803004104
# Generate neighbor vectors for slice co2_slice98
# Mean KNN distance = 80.90644813722425
# Generate neighbor vectors for slice co2_slice99
# Mean KNN distance = 80.7990027672291
# Generate neighbor vectors for slice sa1_slice1
# Mean KNN distance = 69.95876893328078
# Generate neighbor vectors for slice sa1_slice10
# Mean KNN distance = 77.86131164986233
# Generate neighbor vectors for slice sa1_slice11
# Mean KNN distance = 71.7522843283292
# Generate neighbor vectors for slice sa1_slice12
# Mean KNN distance = 69.80865179180799
# Generate neighbor vectors for slice sa1_slice13
# Mean KNN distance = 68.88889360287885
# Generate neighbor vectors for slice sa1_slice14
# Mean KNN distance = 66.2494863239182
# Generate neighbor vectors for slice sa1_slice15
# Mean KNN distance = 66.94308024701346
# Generate neighbor vectors for slice sa1_slice16
# Mean KNN distance = 79.26865250758107
# Generate neighbor vectors for slice sa1_slice17
# Mean KNN distance = 78.35199517841163
# Generate neighbor vectors for slice sa1_slice18
# Mean KNN distance = 77.20683097149877
# Generate neighbor vectors for slice sa1_slice19
# Mean KNN distance = 77.73694388548861
# Generate neighbor vectors for slice sa1_slice2
# Mean KNN distance = 69.80764306422452
# Generate neighbor vectors for slice sa1_slice20
# Mean KNN distance = 76.72736761734868
# Generate neighbor vectors for slice sa1_slice21
# Mean KNN distance = 79.87898666973764
# Generate neighbor vectors for slice sa1_slice22
# Mean KNN distance = 94.06729824325168
# Generate neighbor vectors for slice sa1_slice23
# Mean KNN distance = 98.1994711630011
# Generate neighbor vectors for slice sa1_slice24
# Mean KNN distance = 96.02786708960105
# Generate neighbor vectors for slice sa1_slice25
# Mean KNN distance = 95.5810060844542
# Generate neighbor vectors for slice sa1_slice3
# Mean KNN distance = 69.89294054404643
# Generate neighbor vectors for slice sa1_slice4
# Mean KNN distance = 66.64266433651176
# Generate neighbor vectors for slice sa1_slice5
# Mean KNN distance = 68.26917035478833
# Generate neighbor vectors for slice sa1_slice6
# Mean KNN distance = 70.93200790264262
# Generate neighbor vectors for slice sa1_slice7
# Mean KNN distance = 70.91251871928574
# Generate neighbor vectors for slice sa1_slice8
# Mean KNN distance = 76.58121210179068
# Generate neighbor vectors for slice sa1_slice9
# Mean KNN distance = 79.6126890437022
# Generate neighbor vectors for slice sa2_slice1
# Mean KNN distance = 84.29172903867843
# Generate neighbor vectors for slice sa2_slice2
# Mean KNN distance = 69.99387526504528
# Generate neighbor vectors for slice sa2_slice3
# Mean KNN distance = 64.01188829368196
# CPU times: user 17min 10s, sys: 12.7 s, total: 17min 22s
# Wall time: 17min 22s

# %%
# %%time
# Build a Anndata for the KNN cell types
adata_spatial_fingerprint_subclass = sc.AnnData(spatial_fingerprint_df_subclass)
adata_spatial_fingerprint_subclass.obs = adata.obs.copy()
adata_spatial_fingerprint_subclass.write('adata_spatial_fingerprint_subclass_raw.h5ad')
# Out:
# CPU times: user 8.26 s, sys: 3.97 s, total: 12.2 s
# Wall time: 12.2 s
